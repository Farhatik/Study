# %%
import pandas as pd

# %%
df = pd.read_csv('HW1_var_20.csv', ';')

# %%
df
# Out:
#        Номер варианта       ID                        INCOME_BASE_TYPE  \
# 0                  20  1000020                                   2НДФЛ
# 1                  20  1000040                                   2НДФЛ
# 2                  20  1000060                                   2НДФЛ
# 3                  20  1000080            Поступление зарплаты на счет
# 4                  20  1000100                                   2НДФЛ
# ...               ...      ...                                     ...
# 10237              20  1204760   Форма банка (без печати работодателя)
# 10238              20  1204780   Форма банка (без печати работодателя)
# 10239              20  1204800            Поступление зарплаты на счет
# 10240              20  1204820                                   2НДФЛ
# 10241              20  1204840  Свободная форма с печатью работодателя
#
#       CREDIT_PURPOSE  INSURANCE_FLAG   DTI      SEX  FULL_AGE_CHILD_NUMBER  \
# ...

# %%
df.isna().sum()
# Out:
# Номер варианта              0
# ID                          0
# INCOME_BASE_TYPE           63
# CREDIT_PURPOSE              0
# INSURANCE_FLAG              0
# DTI                       109
# SEX                         0
# FULL_AGE_CHILD_NUMBER       0
# DEPENDANT_NUMBER            0
# EDUCATION                   0
# EMPL_TYPE                  11
# EMPL_SIZE                 109
# BANKACCOUNT_FLAG         2278
# Period_at_work           2279
# age                      2278
# EMPL_PROPERTY            2279
# EMPL_FORM                6316
# FAMILY_STATUS            6316
# max90days                6365
# max60days                6365
# max30days                6365
# max21days                6365
# max14days                6365
# avg_num_delay            6645
# if_zalog                 6633
# num_AccountActive180     6633
# num_AccountActive90      6633
# num_AccountActive60      6633
# Active_to_All_prc        6633
# numAccountActiveAll      6633
# numAccountClosed         6633
# ...

# %%
df.describe()
# Out:
#        Номер варианта            ID  INSURANCE_FLAG  FULL_AGE_CHILD_NUMBER  \
# count         10242.0  1.024200e+04    10242.000000           10242.000000
# mean             20.0  1.102430e+06        0.613650               0.570787
# std               0.0  5.913510e+04        0.486936               0.782160
# min              20.0  1.000020e+06        0.000000               0.000000
# 25%              20.0  1.051225e+06        0.000000               0.000000
# 50%              20.0  1.102430e+06        1.000000               0.000000
# 75%              20.0  1.153635e+06        1.000000               1.000000
# max              20.0  1.204840e+06        1.000000               8.000000
#
#        DEPENDANT_NUMBER  BANKACCOUNT_FLAG  Period_at_work          age  \
# count      10242.000000       7964.000000     7963.000000  7964.000000
# mean           0.005858          0.375188       66.295492    36.437469
# std            0.093562          0.853367       66.554710     8.657505
# ...

# %%
df['ID'].unique()
# Out:
# array([1000020, 1000040, 1000060, ..., 1204800, 1204820, 1204840])
